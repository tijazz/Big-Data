# %% [markdown]
# <a href="https://colab.research.google.com/github/tijazz/Big-Data/blob/main/Week3_Lab(Part2)_optional.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Week3- CMP7203
# By the end of this activity, you will be able to:
# 1.	Identify the key features in CSV data
# 2.	Import CSV into a dataframe and plot values
# 3.	Display the nested structure of a JSON file.
# 4.	Extract data from a JSON file.
# 5.	Identify the major components in semi-structured data from a weather station
# 6. Interact with live tweets from your account

# %%
import tweepy
from textblob import TextBlob
from wordcloud import WordCloud
import pandas as pd
import numpy as np
import re
import matplotlib.pyplot as plt
plt.style.use("fivethirtyeight")

# %%
# Twitter API credentials, add your credential here
consumerKey = ''
consumerSecret = ''
accessToken = ''
accessTokenSecret = ''

# %%
# Creating the authentication object
authenticate = tweepy.OAuthHandler(consumerKey, consumerSecret)
# Setting the access token and access token secret
authenticate.set_access_token(accessToken, accessTokenSecret)
# Creating the API object while passing the authentication information
api = tweepy.API(authenticate, wait_on_rate_limit= True)

# %%
 #Extracting tweets from the twitter user
account = str(input("Enter the twitter account you would like to see: @"))
num = int(input("Enter the number of recent tweets you would like to use: "))
posts = api.user_timeline(screen_name = account, count=num, lang= "en" 
                          ,tweet_mode = "extended")
print("Show the ",num," recent tweets \n")  
i=1
for tweet in posts[0:num]:
  print(str(i) + ') '+ tweet.full_text + '\n')
  i+=1
# Out:
# Enter the twitter account you would like to see: @tijazz94
# Enter the number of recent tweets you would like to use: 30
# Show the  30  recent tweets
#
# 1) RT @RealOlaudah: The Crisis in Ukraine Is Not About Ukraine. It's About Germany.
#
# Thread.
#
# 2) @RealOlaudah @Raatoolaw @Akinscoat @opeyemi_adelowo @hikmah_raji
# Kindly read up this interesting analysis of Russia Ukraine invasion
#
# 3) RT @wakawaka_doctor: Everything about UK IMMIGRATION.( links you need)
#
# To search for companies with tier 2 sponsorship
# https://t.co/3AdW…
#
# 4) RT @jeebryl: Most of us don’t know what to say during Salat Al-janaaza (Burial prayers)​:
#
# Here is a thread for you.
#
# Please share it for t…
#
# 5) RT @wakawaka_doctor: I made a full list here :
#
# https://t.co/eSjs1XkRUl
#
# 6) RT @aiishadahir: “A’oodhu bi kalimaat Allaah al-taammah min kulli shaytaanin wa haammah wa min kulli ‘aynin laammah.”
#
# “I seek refuge in th…
#
# ...

# %%
# Creating a data frame with a column called Tweets so it looks nice
df = pd.DataFrame( [tweet.full_text for tweet in posts] , columns=['Tweets'])
df.index = df.index + 1
df.head()
# Out:
#                                               Tweets
# 1  RT @RealOlaudah: The Crisis in Ukraine Is Not ...
# 2  @RealOlaudah @Raatoolaw @Akinscoat @opeyemi_ad...
# 3  RT @wakawaka_doctor: Everything about UK IMMIG...
# 4  RT @jeebryl: Most of us don’t know what to say...
# 5  RT @wakawaka_doctor: I made a full list here :...
